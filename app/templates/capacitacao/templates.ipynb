# %% [markdown]
# ### Template de Registro (register.html)

# %%
template_register = """
{% extends "base.html" %}
{% block content %}
<div class="container mt-5">
    <div class="row justify-content-center">
        <div class="col-md-6">
            <div class="card">
                <div class="card-header">
                    <h3 class="text-center">Registro de Usuário</h3>
                </div>
                <div class="card-body">
                    <form method="POST" action="{{ url_for('register') }}">
                        {{ form.hidden_tag() }}
                        <div class="mb-3">
                            {{ form.username.label(class="form-label") }}
                            {{ form.username(class="form-control") }}
                        </div>
                        <div class="mb-3">
                            {{ form.email.label(class="form-label") }}
                            {{ form.email(class="form-control") }}
                        </div>
                        <div class="mb-3">
                            {{ form.password.label(class="form-label") }}
                            {{ form.password(class="form-control") }}
                        </div>
                        <div class="mb-3">
                            {{ form.confirm_password.label(class="form-label") }}
                            {{ form.confirm_password(class="form-control") }}
                        </div>
                        <div class="d-grid">
                            {{ form.submit(class="btn btn-primary") }}
                        </div>
                    </form>
                </div>
            </div>
        </div>
    </div>
</div>
{% endblock %}
"""

# %%
template_profissoes = """
{% extends "base.html" %}
{% block content %}
<div class="container mt-5">
    <h2 class="mb-4">Profissões</h2>

    <!-- Formulário para adicionar nova profissão -->
    <div class="card mb-4">
        <div class="card-header">
            <h4>Adicionar Nova Profissão</h4>
        </div>
        <div class="card-body">
            <form method="POST" action="{{ url_for('profissoes') }}">
                {{ form.hidden_tag() }}
                <div class="row">
                    <div class="col-md-8">
                        {{ form.nome.label(class="form-label") }}
                        {{ form.nome(class="form-control") }}
                    </div>
                    <div class="col-md-4">
                        <label class="form-label">&nbsp;</label>
                        <div class="d-grid">
                            {{ form.submit(class="btn btn-primary") }}
                        </div>
                    </div>
                </div>
            </form>
        </div>
    </div>

    <!-- Lista de profissões -->
    <div class="card">
        <div class="card-header">
            <h4>Lista de Profissões</h4>
        </div>
        <div class="card-body">
            <div class="table-responsive">
                <table class="table table-striped">
                    <thead>
                        <tr>
                            <th>ID</th>
                            <th>Nome</th>
                            <th>Ações</th>
                        </tr>
                    </thead>
                    <tbody>
                        {% for profissao in profissoes %}
                        <tr>
                            <td>{{ profissao.id }}</td>
                            <td>{{ profissao.nome }}</td>
                            <td>
                                <a href="{{ url_for('editar_profissao', id=profissao.id) }}" class="btn btn-sm btn-warning">Editar</a>
                                <a href="{{ url_for('excluir_profissao', id=profissao.id) }}" class="btn btn-sm btn-danger" onclick="return confirm('Confirma a exclusão?')">Excluir</a>
                            </td>
                        </tr>
                        {% endfor %}
                    </tbody>
                </table>
            </div>
        </div>
    </div>
</div>
{% endblock %}
"""

# %%
template_error = """
{# error.html #}
{% extends "base.html" %}
{% block content %}
<div class="container mt-5">
    <div class="row justify-content-center">
        <div class="col-md-8">
            <div class="card">
                <div class="card-header bg-danger text-white">
                    <h3 class="text-center mb-0">Erro</h3>
                </div>
                <div class="card-body text-center">
                    <h4>{{ error_title }}</h4>
                    <p class="mb-4">{{ error_message }}</p>
                    <a href="{{ url_for('index') }}" class="btn btn-primary">Voltar para Página Inicial</a>
                </div>
            </div>
        </div>
    </div>
</div>
{% endblock %}
"""

template_404 = """
{# 404.html #}
{% extends "base.html" %}
{% block content %}
<div class="container mt-5">
    <div class="row justify-content-center">
        <div class="col-md-8">
            <div class="card">
                <div class="card-header bg-warning">
                    <h3 class="text-center mb-0">Página não encontrada</h3>
                </div>
                <div class="card-body text-center">
                    <h1 class="display-1">404</h1>
                    <p class="lead mb-4">Desculpe, a página que você está procurando não existe.</p>
                    <a href="{{ url_for('index') }}" class="btn btn-primary">Voltar para Página Inicial</a>
                </div>
            </div>
        </div>
    </div>
</div>
{% endblock %}
"""
